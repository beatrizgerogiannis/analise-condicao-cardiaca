# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Análise Inicial

# %%
df = pd.read_csv('UCMF_raw.csv')
pd.set_option('display.max_columns', None)

import pandas as pd

print("--- PRIMEIRAS 5 LINHAS ---")
display(df.head())

print('--- Colunas e tipos ---')
display(df.dtypes)

print('--- Valores únicos (top 10) por coluna ---')
for c in df.columns:
    print(f'\n-- {c} --')
    display(df[c].value_counts(dropna=False).head(10))

print('--- Resumo de valores ausentes ---')
display(df.isnull().sum().sort_values(ascending=False))

# Estatísticas numéricas e distribuição de idade
num = df.select_dtypes(include=['number'])
if not num.empty:
    print('--- Resumo numérico ---')
    display(num.describe())

    if 'IDADE' in df.columns:
        plt.figure(figsize=(8,4))
        sns.histplot(df['IDADE'].dropna(), kde=True)
        plt.title('Distribuição de IDADE')
        plt.show()

        plt.figure(figsize=(10,4))
        sns.boxplot(x=df['IDADE'].dropna())
        plt.title('Boxplot de IDADE')
        plt.show()

# Correlações entre numéricas
corr = num.corr()
if not corr.empty:
    plt.figure(figsize=(8,6))
    sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
    plt.title('Matriz de correlação (numéricas)')
    plt.show()

print('--- Amostra aleatória (10 linhas) ---')
display(df.sample(10))
# Out:
# --- PRIMEIRAS 5 LINHAS ---
#    ID  Peso  Altura   IMC Atendimento        DN  IDADE Convenio   PULSOS  \
# 0   1   5.0      51  19.0    11/05/06  30/03/06   0.12       GS  Normais
# 1   2   3.5      50  14.0    25/05/05  19/05/05   0.02       GS  Normais
# 2   3   0.0       0   NaN    12/06/01  08/05/05  -4.05     SULA  Normais
# 3   4   8.1      65  19.0    15/10/09  21/04/09   0.50      NaN  Normais
# 4   7  40.0     151  18.0    14/01/08  14/08/95  12.89     SAME  Normais
#
#    PA SISTOLICA  PA DIASTOLICA            PPA NORMAL X ANORMAL      B2  \
# 0           NaN            NaN  Não Calculado          Anormal  Normal
# 1           NaN            NaN  Não Calculado          Anormal  Normal
# 2           NaN            NaN  Não Calculado          Anormal  Normal
# 3           NaN            NaN  Não Calculado          Anormal  Normal
# 4           NaN            NaN  Não Calculado          Anormal  Normal
#
#        SOPRO   FC           HDA 1 HDA2 SEXO                      MOTIVO1  \
# 0  Sistólico  112      Palpitacao  NaN    M  6 - Suspeita de cardiopatia
# 1    ausente  128        Dispneia  NaN    M  6 - Suspeita de cardiopatia
# 2  Sistólico   88   Assintomático  NaN    M                 2 - Check-up
# 3    ausente   92   Assintomático  NaN    M     5 - Parecer cardiológico
# 4    ausente   96  Dor precordial  NaN    M     5 - Parecer cardiológico
#
#                                MOTIVO2
# 0  6 - Palpitação/taquicardia/arritmia
# 1                         6 - Dispnéia
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# --- Colunas e tipos ---
# ID                    int64
# Peso                float64
# Altura                int64
# IMC                 float64
# Atendimento             str
# DN                      str
# IDADE               float64
# Convenio                str
# PULSOS                  str
# PA SISTOLICA        float64
# PA DIASTOLICA       float64
# PPA                     str
# NORMAL X ANORMAL        str
# B2                      str
# SOPRO                   str
# FC                      str
# HDA 1                   str
# HDA2                    str
# SEXO                    str
# MOTIVO1                 str
# MOTIVO2                 str
# dtype: object
# --- Valores únicos (top 10) por coluna ---
#
# -- ID --
# ID
# 1     1
# 2     1
# 3     1
# 4     1
# 7     1
# 8     1
# 9     1
# 10    1
# 11    1
# 12    1
# Name: count, dtype: int64
# -- Peso --
# Peso
# 0.0     2609
# NaN      318
# 15.0     263
# 13.0     229
# 14.0     216
# 16.0     207
# 12.0     202
# 20.0     187
# 18.0     183
# 22.0     175
# Name: count, dtype: int64
# -- Altura --
# Altura
# 0      4460
# 50      140
# 51      134
# 100     130
# 49      126
# 110     125
# 48      123
# 105     118
# 90      117
# 98      113
# Name: count, dtype: int64
# -- IMC --
# IMC
# NaN     4727
# 16.0    1274
# 17.0    1165
# 15.0    1082
# 18.0     854
# 14.0     696
# 19.0     645
# 20.0     499
# 13.0     353
# 21.0     320
# Name: count, dtype: int64
# -- Atendimento --
# Atendimento
# NaN         983
# 12/04/10     24
# 26/05/09     23
# 12/01/10     22
# 15/05/09     19
# 15/10/09     18
# 05/03/09     18
# 18/02/08     18
# 06/03/06     18
# 31/03/09     18
# Name: count, dtype: int64
# -- DN --
# DN
# NaN         1376
# 09/05/04      22
# 19/05/08      14
# 21/06/02      14
# 15/06/06      11
# 10/04/04      10
# 29/08/07      10
# 08/09/99       9
# 24/02/01       9
# 15/04/03       9
# Name: count, dtype: int64
# -- IDADE --
# IDADE
# NaN     1496
# 0.01     195
# 0.00     184
# 0.03      82
# 0.04      79
# 0.05      74
# 0.08      70
# 0.07      67
# 0.09      63
# 0.02      61
# Name: count, dtype: int64
# -- Convenio --
# Convenio
# NaN        4108
# GS         2094
# UR         1479
# SB          450
# GRUPO       408
# CAMED       336
# SA          242
# REAL S.     235
# Camed       227
# Medial      189
# Name: count, dtype: int64
# -- PULSOS --
# PULSOS
# Normais                11531
# NaN                     1194
# Amplos                    52
# Femorais diminuidos       39
# Outro                     36
# Diminuídos                18
# NORMAIS                    2
# AMPLOS                     1
# Name: count, dtype: int64
# -- PA SISTOLICA --
# PA SISTOLICA
# NaN      7730
# 100.0    2094
# 90.0     1163
# 110.0     778
# 120.0     354
# 105.0     175
# 80.0      121
# 95.0      116
# 130.0      96
# 140.0      61
# Name: count, dtype: int64
# -- PA DIASTOLICA --
# PA DIASTOLICA
# NaN     7740
# 60.0    2584
# 70.0     967
# 50.0     596
# 65.0     282
# 80.0     280
# 55.0     133
# 90.0      83
# 75.0      61
# 40.0      49
# Name: count, dtype: int64
# -- PPA --
# PPA
# Não Calculado          9081
# Normal                 1790
# #VALUE!                1496
# NaN                     217
# HAS-2 PAS                73
# Pre-Hipertensão PAD      73
# Pre-Hipertensão PAS      48
# HAS-1 PAS                48
# HAS-1 PAD                26
# HAS-2 PAD                21
# Name: count, dtype: int64
# -- NORMAL X ANORMAL --
# NORMAL X ANORMAL
# Normal     6744
# Anormal    4959
# NaN        1168
# anormal       1
# Normais       1
# Name: count, dtype: int64
# -- B2 --
# B2
# Normal           11098
# NaN               1178
# Hiperfonética      295
# Desdob fixo        149
# Única               77
# Outro               76
# Name: count, dtype: int64
# -- SOPRO --
# SOPRO
# ausente                   7275
# Sistólico                 3648
# NaN                       1167
# sistólico                  723
# contínuo                    28
# Contínuo                    20
# diastólico                   9
# Sistolico e diastólico       3
# Name: count, dtype: int64
# -- FC --
# FC
# NaN    1868
# 100    1509
# 80     1480
# 90     1104
# 88      832
# 96      782
# 120     780
# 92      599
# 72      456
# 110     437
# Name: count, dtype: int64
# -- HDA 1 --
# HDA 1
# Assintomático      6561
# NaN                4270
# Dispneia            541
# Dor precordial      508
# Palpitacao          365
# Cianose             260
# Desmaio/tontura     157
# Outro               124
# Ganho de peso        87
# Name: count, dtype: int64
# -- HDA2 --
# HDA2
# NaN                12466
# Dispneia              83
# Palpitacao            83
# Dor precordial        65
# Cianose               65
# Desmaio/tontura       50
# Outro                 41
# Ganho de peso         19
# Assintomático          1
# Name: count, dtype: int64
# -- SEXO --
# SEXO
# M                6065
# F                4477
# Indeterminado    1417
# Masculino         584
# Feminino          247
# masculino          79
# NaN                 4
# Name: count, dtype: int64
# -- MOTIVO1 --
# MOTIVO1
# 5 - Parecer cardiológico           5352
# 6 - Suspeita de cardiopatia        4285
# 1 - Cardiopatia já estabelecida    1158
# NaN                                1055
# 2 - Check-up                        701
# 7 - Outro                           322
# Name: count, dtype: int64
# -- MOTIVO2 --
# MOTIVO2
# NaN                                    3496
# 5 - Cirurgia                           2940
# 6 - Sopro                              2349
# 1 - Cardiopatia congenica              1041
# Outro                                   824
# 5 - Atividade física                    652
# 6 - Palpitação/taquicardia/arritmia     415
# 6 - Dor precordial                      392
# 6 - HAS/dislipidemia/obesidade          240
# 6 - Dispnéia                            226
# Name: count, dtype: int64
# --- Resumo de valores ausentes ---
# HDA2                12466
# PA DIASTOLICA        7740
# PA SISTOLICA         7730
# IMC                  4727
# HDA 1                4270
# Convenio             4108
# MOTIVO2              3496
# FC                   1868
# IDADE                1496
# DN                   1376
# PULSOS               1194
# B2                   1178
# NORMAL X ANORMAL     1168
# SOPRO                1167
# MOTIVO1              1055
# Atendimento           983
# Peso                  318
# PPA                   217
# SEXO                    4
# Altura                  0
# ID                      0
# dtype: int64
# --- Resumo numérico ---
#                  ID          Peso        Altura          IMC         IDADE  \
# count  12873.000000  12555.000000  12873.000000  8146.000000  11377.000000
# mean    9196.412103     16.614417     66.111474    17.455315      4.856947
# std     5230.972692     16.979814     56.027934    15.008016      8.829742
# min        1.000000    -40.000000      0.000000     0.000000   -113.180000
# 25%     4694.000000      3.400000      0.000000    15.000000      0.930000
# 50%     9222.000000     12.800000     69.000000    17.000000      3.960000
# 75%    13768.000000     24.000000    112.000000    19.000000      8.590000
# max    17873.000000    157.000000    198.000000   848.000000     71.810000
#
#        PA SISTOLICA  PA DIASTOLICA
# count   5143.000000    5133.000000
# mean     101.798561      62.646990
# std       18.901140       9.092261
# min       60.000000       6.000000
# 25%       90.000000      60.000000
# 50%      100.000000      60.000000
# 75%      110.000000      70.000000
# max      990.000000     120.000000
# --- Amostra aleatória (10 linhas) ---
#           ID  Peso  Altura   IMC Atendimento        DN  IDADE  Convenio  \
# 4530    6573   3.6      49  15.0    18/05/04  01/05/04   0.05       NaN
# 5577    8052  28.0       0   NaN    28/05/07  11/03/98   9.56     Ideal
# 5421    7836   5.1      57  16.0    07/05/07  06/03/07   0.18  Unibanco
# 34        46  34.0       0   NaN    05/08/09  30/04/01   8.58       NaN
# 9090   12975  38.0     147  18.0    23/05/06  17/02/95  11.68   NORCLIN
# 3493    5083   4.1      56  13.0    03/07/06  27/05/06   0.11     CAMED
# 4830    7016  12.0      89  15.0    13/05/05  03/10/03   1.67     CAMED
# 10293  14705   3.9      51  15.0    25/09/09  18/08/09   0.11       NaN
# 3479    5062  13.7      90  17.0    21/11/06  16/05/03   3.65      SULA
# 10017  14310   0.0       0   NaN         NaN       NaN    NaN       NaN
#
#         PULSOS  PA SISTOLICA  PA DIASTOLICA            PPA NORMAL X ANORMAL  \
# 4530   Normais           NaN            NaN  Não Calculado          Anormal
# 5577   Normais         100.0           60.0  Não Calculado           Normal
# 5421       NaN           NaN            NaN  Não Calculado              NaN
# 34     Normais         100.0           60.0  Não Calculado          Anormal
# 9090   Normais           NaN            NaN  Não Calculado          Anormal
# 3493   Normais           NaN            NaN  Não Calculado           Normal
# 4830   Normais           NaN            NaN  Não Calculado           Normal
# 10293  Normais           NaN            NaN  Não Calculado          Anormal
# 3479   Normais           NaN            NaN  Não Calculado           Normal
# 10017      NaN           NaN            NaN        #VALUE!              NaN
#
#            B2      SOPRO   FC          HDA 1 HDA2           SEXO  \
# 4530    Única  Sistólico  130            NaN  NaN              F
# 5577   Normal    ausente   80            NaN  NaN              M
# 5421      NaN        NaN  NaN            NaN  NaN              M
# 34     Normal  Sistólico   80  Assintomático  NaN              M
# 9090   Normal  Sistólico   88       Dispneia  NaN              F
# 3493   Normal    ausente  120  Assintomático  NaN              F
# 4830   Normal    ausente  100  Assintomático  NaN              M
# 10293  Normal  Sistólico  102  Assintomático  NaN              F
# 3479   Normal    ausente   90            NaN  NaN              F
# 10017     NaN        NaN  NaN            NaN  NaN  Indeterminado
#
#                                MOTIVO1                    MOTIVO2
# 4530       6 - Suspeita de cardiopatia                  6 - Sopro
# 5577          5 - Parecer cardiológico       5 - Atividade física
# 5421       6 - Suspeita de cardiopatia                      Outro
# 34         6 - Suspeita de cardiopatia                  6 - Sopro
# 9090       6 - Suspeita de cardiopatia                  6 - Sopro
# 3493   1 - Cardiopatia já estabelecida  1 - Cardiopatia congenica
# 4830          5 - Parecer cardiológico               5 - Cirurgia
# 10293                        7 - Outro                      Outro
# 3479          5 - Parecer cardiológico               5 - Cirurgia
# 10017                              NaN                        NaN

# %% [markdown]
# ## Tratamento Inicial

# %%
import numpy as np

# 1. Padronização da Variável Alvo e Sexo
df['NORMAL X ANORMAL'] = df['NORMAL X ANORMAL'].str.title().replace('Normais', 'Normal')
df['SEXO'] = df['SEXO'].str.upper().str[0] # Padroniza pegando apenas a primeira letra

# 2. Remoção de Outliers Extremos (Substituindo por NaN)
# Filtrando idades para a faixa do estudo (0 a 19 anos)
df.loc[(df['IDADE'] < 0) | (df['IDADE'] > 19), 'IDADE'] = np.nan 

# Tratando Peso e Altura impossíveis
df.loc[df['Peso'] <= 0, 'Peso'] = np.nan
df.loc[df['Altura'] <= 0, 'Altura'] = np.nan

# Tratando Pressão Arterial irreal (ex: maior que 300)
df.loc[df['PA SISTOLICA'] > 300, 'PA SISTOLICA'] = np.nan
    
# 1. SEXO: Converter "Indeterminado" para NaN
df['SEXO'] = df['SEXO'].replace('I', np.nan)

# 2. SOPRO: Padronizar as categorias (corrigindo minúsculas)
df['SOPRO'] = df['SOPRO'].replace({
    'sistólico': 'Sistólico',
    'contínuo': 'Contínuo'
})

# 3. PPA: Remover erro de fórmula e transformar em NaN
df['PPA'] = df['PPA'].replace('#VALUE!', np.nan)

# 4. PULSOS: Padronizar as categorias (corrigindo maiúsculas)
df['PULSOS'] = df['PULSOS'].replace({
    'NORMAIS': 'Normais',
    'AMPLOS': 'Amplos'
})

# Seleciona apenas as colunas de texto (categóricas)
cat = df.select_dtypes(include=['object', 'category'])

if not cat.empty:
    print('--- Quantidade de valores únicos por coluna categórica ---')
    # .nunique() conta os valores únicos. O sort_values organiza do maior para o menor.
    display(cat.nunique().sort_values(ascending=False))

print('--- Detalhamento de valores únicos (Colunas Categóricas) ---')
for c in cat.columns:
    quantidade_unicos = df[c].nunique()
    print(f'\n-- {c} (Total de valores únicos: {quantidade_unicos}) --')
    # O dropna=False permite que você veja também quantos NaNs existem
    display(df[c].value_counts(dropna=False))
    
print('--- Resumo de valores ausentes ---')
display(df.isnull().sum().sort_values(ascending=False))
# Out:
# --- Quantidade de valores únicos por coluna categórica ---
# /tmp/ipykernel_69436/1030362059.py:37: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat = df.select_dtypes(include=['object', 'category'])
# DN                  5483
# Atendimento         2027
# Convenio             374
# FC                   118
# MOTIVO2               16
# PPA                    8
# HDA2                   8
# HDA 1                  8
# B2                     5
# PULSOS                 5
# MOTIVO1                5
# SOPRO                  5
# NORMAL X ANORMAL       2
# SEXO                   2
# dtype: int64
# --- Detalhamento de valores únicos (Colunas Categóricas) ---
#
# -- Atendimento (Total de valores únicos: 2027) --
# Atendimento
# NaN         983
# 12/04/10     24
# 26/05/09     23
# 12/01/10     22
# 15/05/09     19
#            ...
# 39797         1
# 38082         1
# 38313         1
# 25/05/10      1
# 40147         1
# Name: count, Length: 2028, dtype: int64
# -- DN (Total de valores únicos: 5483) --
# DN
# NaN         1376
# 09/05/04      22
# 19/05/08      14
# 21/06/02      14
# 15/06/06      11
#             ...
# 37381          1
# 13/09/98       1
# 16/02/84       1
# 03/12/27       1
# 21/07/92       1
# Name: count, Length: 5484, dtype: int64
# -- Convenio (Total de valores únicos: 374) --
# Convenio
# NaN                  4108
# GS                   2094
# UR                   1479
# SB                    450
# GRUPO                 408
#                      ...
# Real saúde              1
# C. Coração              1
# Jorge de Medeiros       1
# Fisco Saude             1
# S.Am                    1
# Name: count, Length: 375, dtype: int64
# -- PULSOS (Total de valores únicos: 5) --
# PULSOS
# Normais                11533
# NaN                     1194
# Amplos                    53
# Femorais diminuidos       39
# Outro                     36
# Diminuídos                18
# Name: count, dtype: int64
# -- PPA (Total de valores únicos: 8) --
# PPA
# Não Calculado          9081
# Normal                 1790
# NaN                    1713
# HAS-2 PAS                73
# Pre-Hipertensão PAD      73
# Pre-Hipertensão PAS      48
# HAS-1 PAS                48
# HAS-1 PAD                26
# HAS-2 PAD                21
# Name: count, dtype: int64
# -- NORMAL X ANORMAL (Total de valores únicos: 2) --
# NORMAL X ANORMAL
# Normal     6745
# Anormal    4960
# NaN        1168
# Name: count, dtype: int64
# -- B2 (Total de valores únicos: 5) --
# B2
# Normal           11098
# NaN               1178
# Hiperfonética      295
# Desdob fixo        149
# Única               77
# Outro               76
# Name: count, dtype: int64
# -- SOPRO (Total de valores únicos: 5) --
# SOPRO
# ausente                   7275
# Sistólico                 4371
# NaN                       1167
# Contínuo                    48
# diastólico                   9
# Sistolico e diastólico       3
# Name: count, dtype: int64
# -- FC (Total de valores únicos: 118) --
# FC
# NaN        1868
# 100        1509
# 80         1480
# 90         1104
# 88          832
#            ...
# 8             1
# 91            1
# 120-160       1
# 143           1
# 105           1
# Name: count, Length: 119, dtype: int64
# -- HDA 1 (Total de valores únicos: 8) --
# HDA 1
# Assintomático      6561
# NaN                4270
# Dispneia            541
# Dor precordial      508
# Palpitacao          365
# Cianose             260
# Desmaio/tontura     157
# Outro               124
# Ganho de peso        87
# Name: count, dtype: int64
# -- HDA2 (Total de valores únicos: 8) --
# HDA2
# NaN                12466
# Dispneia              83
# Palpitacao            83
# Dor precordial        65
# Cianose               65
# Desmaio/tontura       50
# Outro                 41
# Ganho de peso         19
# Assintomático          1
# Name: count, dtype: int64
# -- SEXO (Total de valores únicos: 2) --
# SEXO
# M      6728
# F      4724
# NaN    1421
# Name: count, dtype: int64
# -- MOTIVO1 (Total de valores únicos: 5) --
# MOTIVO1
# 5 - Parecer cardiológico           5352
# 6 - Suspeita de cardiopatia        4285
# 1 - Cardiopatia já estabelecida    1158
# NaN                                1055
# 2 - Check-up                        701
# 7 - Outro                           322
# Name: count, dtype: int64
# -- MOTIVO2 (Total de valores únicos: 16) --
# MOTIVO2
# NaN                                    3496
# 5 - Cirurgia                           2940
# 6 - Sopro                              2349
# 1 - Cardiopatia congenica              1041
# Outro                                   824
# 5 - Atividade física                    652
# 6 - Palpitação/taquicardia/arritmia     415
# 6 - Dor precordial                      392
# 6 - HAS/dislipidemia/obesidade          240
# 6 - Dispnéia                            226
# 6 - Cianose                             145
# 1 - Cardiopatia adquirida                92
# 6 - Cardiopatia na familia               35
# 5 - Uso de cisaprida                      9
# 6 - Cansaço                               7
# 6 - Alterações de pulso/perfusão          5
# 6 - Cianose e dispnéia                    5
# Name: count, dtype: int64
