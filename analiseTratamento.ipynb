# %% [markdown]
# Trabalho Final de Mineração de Dados
# Resumo: Estudo de caso aplicado em uma base de dados real do setor de saúde. O objetivo é utilizar o processo de KDD (Knowledge Discovery in Databases) para a identificação de padrões, predição e extração de conhecimento sobre patologias cardíacas em crianças e jovens.
# Aplicando os processos de Seleção de dados alvo, pré-processamento e limpeza, transformação, mineração de dados e Avaliação.

# %% [markdown]
# 1° parte: analisar o que temos dentro do dataset e as variações de dados

# %%
import pandas as pd

df = pd.read_csv('UCMF_raw.csv')

# Loop para analisar cada coluna separadamente de forma isolada
for coluna in df.columns:
    print("\n" + "="*70)
    print(f"  ANÁLISE DE CADA VARIÁVEL: {coluna}")
    print("="*70)
    
    # 1. Informações básicas de tipo e preenchimento
    tipo = df[coluna].dtype
    total_linhas = len(df)
    nulos = df[coluna].isnull().sum()
    
    print(f"• Tipo de dado na coluna: {tipo}")
    print(f"• Linhas preenchidas: {df[coluna].count()} / {total_linhas}")
    print(f"• Linhas vazias (nulas): {nulos} ({ (nulos/total_linhas)*100 :.2f}%)")
    
    # 2. Extração de todos os valores diferentes (Únicos)
    # .dropna() remove os nulos temporariamente apenas para listar os valores reais existentes
    valores_distintos = df[coluna].dropna().unique()
    qtd_distintos = len(valores_distintos)
    
    print(f"• Quantidade de valores distintos/diferentes nesta coluna: {qtd_distintos}")
    print("-" * 70)
    
    # CASO A: Colunas com poucos valores diferentes (Ex: SEXO, SOPRO, B2, NORMAL X ANORMAL)
    if qtd_distintos <= 35:
        print("-> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:")
        print(valores_distintos)
        
        print("\n-> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):")
        frequencia = df[coluna].value_counts(dropna=False)
        percentual = df[coluna].value_counts(dropna=False, normalize=True) * 100
        
        tabela_separada = pd.DataFrame({
            'Quantidade (Qtd)': frequencia,
            'Proporção (%)': percentual.round(2)
        })
        print(tabela_separada)
        
    # CASO B: Colunas contínuas ou identificadores com muitos valores (Ex: ID, IMC, IDADE, FC)
    else:
        print(f"Nota: Como esta coluna possui muitos valores diferentes ({qtd_distintos}),")
        print("exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:")
        print(valores_distintos[:10])
        
        # Se for numérico, nos mostra as fronteiras (mínimo e máximo)
        if pd.api.types.is_numeric_dtype(df[coluna]):
            print("\n-> RESUMO DOS EXTREMOS NUMÉRICOS:")
            print(f"   - Menor valor real encontrado: {df[coluna].min()}")
            print(f"   - Maior valor real encontrado: {df[coluna].max()}")
            print(f"   - Média geral da coluna: {df[coluna].mean():.2f}")
            print(f"   - Mediana (valor do meio): {df[coluna].median():.2f}")
            
    print("\n" + "."*70) # Divisor de fim de bloco de coluna
# Out:
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: ID
# ======================================================================
# • Tipo de dado na coluna: int64
# • Linhas preenchidas: 12873 / 12873
# • Linhas vazias (nulas): 0 (0.00%)
# • Quantidade de valores distintos/diferentes nesta coluna: 12873
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (12873),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# [ 1  2  3  4  7  8  9 10 11 12]
#
# -> RESUMO DOS EXTREMOS NUMÉRICOS:
#    - Menor valor real encontrado: 1
#    - Maior valor real encontrado: 17873
#    - Média geral da coluna: 9196.41
#    - Mediana (valor do meio): 9222.00
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: Peso
# ======================================================================
# • Tipo de dado na coluna: float64
# • Linhas preenchidas: 12555 / 12873
# • Linhas vazias (nulas): 318 (2.47%)
# • Quantidade de valores distintos/diferentes nesta coluna: 627
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (627),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# [ 5.   3.5  0.   8.1 40.  28.   8.   5.1 24.5 18. ]
#
# -> RESUMO DOS EXTREMOS NUMÉRICOS:
#    - Menor valor real encontrado: -40.0
#    - Maior valor real encontrado: 157.0
#    - Média geral da coluna: 16.61
#    - Mediana (valor do meio): 12.80
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: Altura
# ======================================================================
# • Tipo de dado na coluna: int64
# • Linhas preenchidas: 12873 / 12873
# • Linhas vazias (nulas): 0 (0.00%)
# • Quantidade de valores distintos/diferentes nesta coluna: 165
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (165),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# [ 51  50   0  65 151 117  61  57 122  98]
#
# -> RESUMO DOS EXTREMOS NUMÉRICOS:
#    - Menor valor real encontrado: 0
#    - Maior valor real encontrado: 198
#    - Média geral da coluna: 66.11
#    - Mediana (valor do meio): 69.00
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: IMC
# ======================================================================
# • Tipo de dado na coluna: float64
# • Linhas preenchidas: 8146 / 12873
# • Linhas vazias (nulas): 4727 (36.72%)
# • Quantidade de valores distintos/diferentes nesta coluna: 56
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (56),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# [19. 14. 18. 20. 21. 16. 17. 13. 22. 12.]
#
# -> RESUMO DOS EXTREMOS NUMÉRICOS:
#    - Menor valor real encontrado: 0.0
#    - Maior valor real encontrado: 848.0
#    - Média geral da coluna: 17.46
#    - Mediana (valor do meio): 17.00
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: Atendimento
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11890 / 12873
# • Linhas vazias (nulas): 983 (7.64%)
# • Quantidade de valores distintos/diferentes nesta coluna: 2027
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (2027),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# <StringArray>
# ['11/05/06', '25/05/05', '12/06/01', '15/10/09', '14/01/08', '01/09/05',
#  '19/06/06', '06/09/07', '03/12/07', '20/06/03']
# Length: 10, dtype: str
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: DN
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11497 / 12873
# • Linhas vazias (nulas): 1376 (10.69%)
# • Quantidade de valores distintos/diferentes nesta coluna: 5483
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (5483),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# <StringArray>
# ['30/03/06', '19/05/05', '08/05/05', '21/04/09', '14/08/95', '28/12/99',
#  '20/03/06', '20/06/07', '29/11/01', '18/06/00']
# Length: 10, dtype: str
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: IDADE
# ======================================================================
# • Tipo de dado na coluna: float64
# • Linhas preenchidas: 11377 / 12873
# • Linhas vazias (nulas): 1496 (11.62%)
# • Quantidade de valores distintos/diferentes nesta coluna: 1879
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (1879),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# [ 0.12  0.02 -4.05  0.5  12.89  5.89  0.26  0.22  6.24  3.12]
#
# -> RESUMO DOS EXTREMOS NUMÉRICOS:
#    - Menor valor real encontrado: -113.18
#    - Maior valor real encontrado: 71.81
#    - Média geral da coluna: 4.86
#    - Mediana (valor do meio): 3.96
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: Convenio
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 8765 / 12873
# • Linhas vazias (nulas): 4108 (31.91%)
# • Quantidade de valores distintos/diferentes nesta coluna: 374
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (374),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# <StringArray>
# ['GS', 'SULA', 'SAME', 'UR', 'Grupo', 'PART', 'SB', 'SA', 'S.America', 'UG']
# Length: 10, dtype: str
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: PULSOS
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11679 / 12873
# • Linhas vazias (nulas): 1194 (9.28%)
# • Quantidade de valores distintos/diferentes nesta coluna: 7
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# [            'Normais',             'NORMAIS',              'Amplos',
#               'AMPLOS', 'Femorais diminuidos',               'Outro',
#          'Diminuídos ']
# Length: 7, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                      Quantidade (Qtd)  Proporção (%)
# PULSOS
# Normais                         11531          89.58
# NaN                              1194           9.28
# Amplos                             52           0.40
# Femorais diminuidos                39           0.30
# Outro                              36           0.28
# Diminuídos                         18           0.14
# NORMAIS                             2           0.02
# AMPLOS                              1           0.01
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: PA SISTOLICA
# ======================================================================
# • Tipo de dado na coluna: float64
# • Linhas preenchidas: 5143 / 12873
# • Linhas vazias (nulas): 7730 (60.05%)
# • Quantidade de valores distintos/diferentes nesta coluna: 44
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (44),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# [110. 100.  90. 140. 105.  95. 120. 130. 115.  80.]
#
# -> RESUMO DOS EXTREMOS NUMÉRICOS:
#    - Menor valor real encontrado: 60.0
#    - Maior valor real encontrado: 990.0
#    - Média geral da coluna: 101.80
#    - Mediana (valor do meio): 100.00
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: PA DIASTOLICA
# ======================================================================
# • Tipo de dado na coluna: float64
# • Linhas preenchidas: 5133 / 12873
# • Linhas vazias (nulas): 7740 (60.13%)
# • Quantidade de valores distintos/diferentes nesta coluna: 30
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# [ 65.  60.  90.  50.  70.  55.  80.  58.  40.  45.  75.  72.  57.  78.
#  100.  85.  35.  67.  68. 110. 120.  62.  56.  63.  95. 115.  64.  23.
#   52.   6.]
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                Quantidade (Qtd)  Proporção (%)
# PA DIASTOLICA
# NaN                        7740          60.13
# 60.0                       2584          20.07
# 70.0                        967           7.51
# 50.0                        596           4.63
# 65.0                        282           2.19
# 80.0                        280           2.18
# 55.0                        133           1.03
# 90.0                         83           0.64
# 75.0                         61           0.47
# 40.0                         49           0.38
# 45.0                         22           0.17
# 85.0                         14           0.11
# 100.0                        13           0.10
# 58.0                          9           0.07
# 95.0                          6           0.05
# 68.0                          5           0.04
# 110.0                         4           0.03
# 78.0                          3           0.02
# 35.0                          3           0.02
# 120.0                         3           0.02
# 62.0                          3           0.02
# 56.0                          3           0.02
# 63.0                          2           0.02
# 72.0                          1           0.01
# 57.0                          1           0.01
# 67.0                          1           0.01
# 115.0                         1           0.01
# 64.0                          1           0.01
# 23.0                          1           0.01
# 52.0                          1           0.01
# 6.0                           1           0.01
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: PPA
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 12656 / 12873
# • Linhas vazias (nulas): 217 (1.69%)
# • Quantidade de valores distintos/diferentes nesta coluna: 9
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# [      'Não Calculado', 'Pre-Hipertensão PAS',              'Normal',
#            'HAS-2 PAS',             '#VALUE!',           'HAS-2 PAD',
#            'HAS-1 PAD', 'Pre-Hipertensão PAD',           'HAS-1 PAS']
# Length: 9, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                      Quantidade (Qtd)  Proporção (%)
# PPA
# Não Calculado                    9081          70.54
# Normal                           1790          13.91
# #VALUE!                          1496          11.62
# NaN                               217           1.69
# HAS-2 PAS                          73           0.57
# Pre-Hipertensão PAD                73           0.57
# Pre-Hipertensão PAS                48           0.37
# HAS-1 PAS                          48           0.37
# HAS-1 PAD                          26           0.20
# HAS-2 PAD                          21           0.16
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: NORMAL X ANORMAL
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11705 / 12873
# • Linhas vazias (nulas): 1168 (9.07%)
# • Quantidade de valores distintos/diferentes nesta coluna: 4
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# ['Anormal', 'Normal', 'anormal', 'Normais']
# Length: 4, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                   Quantidade (Qtd)  Proporção (%)
# NORMAL X ANORMAL
# Normal                        6744          52.39
# Anormal                       4959          38.52
# NaN                           1168           9.07
# anormal                          1           0.01
# Normais                          1           0.01
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: B2
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11695 / 12873
# • Linhas vazias (nulas): 1178 (9.15%)
# • Quantidade de valores distintos/diferentes nesta coluna: 5
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# ['Normal', 'Outro', 'Hiperfonética', 'Desdob fixo', 'Única']
# Length: 5, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                Quantidade (Qtd)  Proporção (%)
# B2
# Normal                    11098          86.21
# NaN                        1178           9.15
# Hiperfonética               295           2.29
# Desdob fixo                 149           1.16
# Única                        77           0.60
# Outro                        76           0.59
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: SOPRO
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11706 / 12873
# • Linhas vazias (nulas): 1167 (9.07%)
# • Quantidade de valores distintos/diferentes nesta coluna: 7
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# [             'Sistólico',                'ausente',              'sistólico',
#                'contínuo',             'diastólico',               'Contínuo',
#  'Sistolico e diastólico']
# Length: 7, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                         Quantidade (Qtd)  Proporção (%)
# SOPRO
# ausente                             7275          56.51
# Sistólico                           3648          28.34
# NaN                                 1167           9.07
# sistólico                            723           5.62
# contínuo                              28           0.22
# Contínuo                              20           0.16
# diastólico                             9           0.07
# Sistolico e diastólico                 3           0.02
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: FC
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11005 / 12873
# • Linhas vazias (nulas): 1868 (14.51%)
# • Quantidade de valores distintos/diferentes nesta coluna: 118
# ----------------------------------------------------------------------
# Nota: Como esta coluna possui muitos valores diferentes (118),
# exibir todos criaria uma lista muito longa. Veja os 10 primeiros exemplos de valores únicos:
# <StringArray>
# ['112', '128', '88', '92', '96', '80', '120', '110', '100', '52']
# Length: 10, dtype: str
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: HDA 1
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 8603 / 12873
# • Linhas vazias (nulas): 4270 (33.17%)
# • Quantidade de valores distintos/diferentes nesta coluna: 8
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# [     'Palpitacao',        'Dispneia',   'Assintomático',  'Dor precordial',
#  'Desmaio/tontura',         'Cianose',           'Outro',   'Ganho de peso']
# Length: 8, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                  Quantidade (Qtd)  Proporção (%)
# HDA 1
# Assintomático                6561          50.97
# NaN                          4270          33.17
# Dispneia                      541           4.20
# Dor precordial                508           3.95
# Palpitacao                    365           2.84
# Cianose                       260           2.02
# Desmaio/tontura               157           1.22
# Outro                         124           0.96
# Ganho de peso                  87           0.68
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: HDA2
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 407 / 12873
# • Linhas vazias (nulas): 12466 (96.84%)
# • Quantidade de valores distintos/diferentes nesta coluna: 8
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# [       'Dispneia',      'Palpitacao', 'Desmaio/tontura',  'Dor precordial',
#    'Assintomático',         'Cianose',           'Outro',   'Ganho de peso']
# Length: 8, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                  Quantidade (Qtd)  Proporção (%)
# HDA2
# NaN                         12466          96.84
# Dispneia                       83           0.64
# Palpitacao                     83           0.64
# Dor precordial                 65           0.50
# Cianose                        65           0.50
# Desmaio/tontura                50           0.39
# Outro                          41           0.32
# Ganho de peso                  19           0.15
# Assintomático                   1           0.01
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: SEXO
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 12869 / 12873
# • Linhas vazias (nulas): 4 (0.03%)
# • Quantidade de valores distintos/diferentes nesta coluna: 6
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# ['M', 'F', 'Indeterminado', 'Masculino', 'Feminino', 'masculino']
# Length: 6, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                Quantidade (Qtd)  Proporção (%)
# SEXO
# M                          6065          47.11
# F                          4477          34.78
# Indeterminado              1417          11.01
# Masculino                   584           4.54
# Feminino                    247           1.92
# masculino                    79           0.61
# NaN                           4           0.03
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: MOTIVO1
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 11818 / 12873
# • Linhas vazias (nulas): 1055 (8.20%)
# • Quantidade de valores distintos/diferentes nesta coluna: 5
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# [    '6 - Suspeita de cardiopatia',                    '2 - Check-up',
#         '5 - Parecer cardiológico', '1 - Cardiopatia já estabelecida',
#                        '7 - Outro']
# Length: 5, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                                  Quantidade (Qtd)  Proporção (%)
# MOTIVO1
# 5 - Parecer cardiológico                     5352          41.58
# 6 - Suspeita de cardiopatia                  4285          33.29
# 1 - Cardiopatia já estabelecida              1158           9.00
# NaN                                          1055           8.20
# 2 - Check-up                                  701           5.45
# 7 - Outro                                     322           2.50
#
# ......................................................................
#
# ======================================================================
#   ANÁLISE ISOLADA DA VARIÁVEL: MOTIVO2
# ======================================================================
# • Tipo de dado na coluna: str
# • Linhas preenchidas: 9377 / 12873
# • Linhas vazias (nulas): 3496 (27.16%)
# • Quantidade de valores distintos/diferentes nesta coluna: 16
# ----------------------------------------------------------------------
# -> LISTA DE TODOS OS VALORES DIFERENTES PRESENTES:
# <StringArray>
# ['6 - Palpitação/taquicardia/arritmia',                        '6 - Dispnéia',
#                         '5 - Cirurgia',                           '6 - Sopro',
#            '1 - Cardiopatia adquirida',           '1 - Cardiopatia congenica',
#                   '6 - Dor precordial',                '5 - Atividade física',
#                          '6 - Cianose',    '6 - Alterações de pulso/perfusão',
#       '6 - HAS/dislipidemia/obesidade',                               'Outro',
#           '6 - Cardiopatia na familia',                         '6 - Cansaço',
#                 '5 - Uso de cisaprida',              '6 - Cianose e dispnéia']
# Length: 16, dtype: str
#
# -> DISTRIBUIÇÃO E FREQUÊNCIA DE CADA VALOR (Incluindo Nulos):
#                                      Quantidade (Qtd)  Proporção (%)
# MOTIVO2
# NaN                                              3496          27.16
# 5 - Cirurgia                                     2940          22.84
# 6 - Sopro                                        2349          18.25
# 1 - Cardiopatia congenica                        1041           8.09
# Outro                                             824           6.40
# 5 - Atividade física                              652           5.06
# 6 - Palpitação/taquicardia/arritmia               415           3.22
# 6 - Dor precordial                                392           3.05
# 6 - HAS/dislipidemia/obesidade                    240           1.86
# 6 - Dispnéia                                      226           1.76
# 6 - Cianose                                       145           1.13
# 1 - Cardiopatia adquirida                          92           0.71
# 6 - Cardiopatia na familia                         35           0.27
# 5 - Uso de cisaprida                                9           0.07
# 6 - Cansaço                                         7           0.05
# 6 - Alterações de pulso/perfusão                    5           0.04
# 6 - Cianose e dispnéia                              5           0.04
#
# ......................................................................

# %% [markdown]
# O que encontramos após essa análise inicial?
# - ID: Variável irrelevante para o processo;
# - Peso: Possui dados faltantes (2.47%) e possui peso negativo, o que não é possível;
# - Altura: Possui altura nula, o que não é possível;
# - IMC: Possui dados faltantes (36.72%), caso tenhamos peso e altura, é possível calcular, menor valor foi 0;
# - Atendimento: Pode ser relevante caso idade do paciente não foi coletado, dados faltantes (7.64%);
# - Data de nascimento: Possui dados faltantes (10.69%), pode ser prejudicial pois o estudo é por faixa etária;
# - Idade: Possui dados faltantes (11.62%), e com valores negativos, o que não é possível;
# - Convênio: Variável irrelevante para o processo;
# - Pulsos: Possui dados faltantes (9.28%), com palavras igual escritas de formas diferentes;
# - PA sistólica: Possui muitos dados faltantes (60.05%), pode atrapalhar o processo;
# - PA diastólica: Possui muitos dados faltantes (60.13%), pode atrapalhar o processo;
# - PPA: Pode substituir os PAs, mas possui dados faltantes (1.69%), não calculado (70.54%) e sem valor (11.62%);
# - Patologia: Possui dados faltantes (9.07%), e palavras iguais escritas de formas diferentes;
# - B2: Possui dados faltantes (9.15%);
# - Sopro: Possui dados faltantes (9.07%) e palavras iguais escritas de formas diferentes;
# - Frequencia cardíaca: Possui dados faltantes (14.51%);
# - Histórico de Doença 1: Possui dados faltantes (33.17%);
# - Histórico de Doença 2: Possui dados faltantes (96.84%);
# - Sexo: Poucos dados faltantes (0.03%), mas palavras iguais escritas de formas diferentes;
# - Motivo 1: Possui dados faltantes (8.20%);
# - Motivo 2: Possui dados faltantes (27.16%);
